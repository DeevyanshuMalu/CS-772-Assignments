# %%
import json

# %%
with open('hin/hin_test.jsonl', 'r') as f:
    data = f.readlines()
data = [json.loads(line) for line in data]
data[0]
# Out:
# {'unique_identifier': 'hin1',
#  'native word': 'मैट्रोलॉजिस्ट',
#  'english word': 'maitrologist',
#  'source': 'AK-Freq'}

# %%
[c for c in data[0]['native word']], [c for c in data[0]['english word']]
# Out:
# (['म', 'ै', 'ट', '्', 'र', 'ो', 'ल', 'ॉ', 'ज', 'ि', 'स', '्', 'ट'],
#  ['m', 'a', 'i', 't', 'r', 'o', 'l', 'o', 'g', 'i', 's', 't'])
